# %%
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(t, y):
    return 2*y

# %%
t0 = 0
y0 = 1
t = np.linspace(t0, 3, 100) 
sol = solve_ivp(f, [t0, 3], [y0], t_eval=t)

# %%
plt.plot(sol.t, sol.y[0])
